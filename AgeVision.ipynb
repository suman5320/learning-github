# %% [markdown]
# <a href="https://colab.research.google.com/github/suman5320/learning-github/blob/main/AgeVision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, GlobalAveragePooling2D,
                                       Dense, Dropout, BatchNormalization)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
# ==================== CONFIGURATION ====================
IMG_SIZE = 128
BATCH_SIZE = 32
NUM_CLASSES = 5
EPOCHS = 50
SEED = 42

age_group_labels = [
    'Child (0-10)',
    'Teenager (11-17)',
    'Adult (18-35)',
    'Middle Age (36-59)',
    'Senior (60+)'
]

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !kaggle datasets download -d jangedoo/utkface-new
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/jangedoo/utkface-new
# License(s): copyright-authors
# Downloading utkface-new.zip to /content
#  81% 268M/331M [00:06<00:01, 38.5MB/s]
# 100% 331M/331M [00:06<00:00, 55.4MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/utkface-new.zip','r')
zip_ref.extractall('/content')
zip_ref.close()

# %% [markdown]
# In UTKFace, the labels are encoded directly in the image filenames.
#
#
#
# Each file has the format:
#
# [age] _[gender] _[race] _[date&time].jpg
#
#
# age → integer (0–116)
#
# gender → 0 = male, 1 = female
#
# race → 0 = White, 1 = Black, 2 = Asian, 3 = Indian, 4 = Others
#
# date&time → not needed for labels
#
# Example:
#
# 25_0_2_20170116174525125.jpg
#
#
# means:
#
# Age = 25
#
# Gender = 0 (male)
#
# Race = 2 (Asian)

# %%
# ==================== HELPER FUNCTIONS ====================
def age_to_group(age):
    """Convert numerical age to age group index"""
    if age <= 10:
        return 0
    elif 11 <= age <= 17:
        return 1
    elif 18 <= age <= 35:
        return 2
    elif 36 <= age <= 59:
        return 3
    else:
        return 4

# %%
def plot_class_distribution(df, title="Class Distribution"):
    """Plot the distribution of classes"""
    plt.figure(figsize=(10, 5))
    counts = df['class'].value_counts().sort_index()
    labels = [age_group_labels[int(i)] for i in counts.index]
    plt.bar(labels, counts.values, color='skyblue', edgecolor='black')
    plt.title(title, fontsize=14, fontweight='bold')
    plt.xlabel('Age Group')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    for i, v in enumerate(counts.values):
        plt.text(i, v + 50, str(v), ha='center', fontweight='bold')
    plt.tight_layout()
    plt.show()

# %%
# ==================== DATA PREPARATION ====================
print("=" * 60)
print("LOADING DATA")
print("=" * 60)

data_dir = r"/content/UTKFace"
files = os.listdir(data_dir)
# Out:
# ============================================================
# LOADING DATA
# ============================================================

# %%
# Parse filenames to extract ages
ages = []
valid_files = []
for f in files:
    try:
        age = int(f.split("_")[0])
        ages.append(age)
        valid_files.append(f)
    except:
        continue

age_groups = [age_to_group(a) for a in ages]

# %%
# Create dataframe
df = pd.DataFrame({
    "filename": valid_files,
    "class": age_groups
})
df["class"] = df["class"].astype(str)

print(f"\nTotal images: {len(df)}")
print(f"\nClass distribution:")
for i in range(NUM_CLASSES):
    count = (df['class'] == str(i)).sum()
    print(f"  {age_group_labels[i]}: {count}")

plot_class_distribution(df, "Dataset Class Distribution")
# Out:
# Total images: 23708
#
# Class distribution:
#   Child (0-10): 3218
#   Teenager (11-17): 1015
#   Adult (18-35): 10874
#   Middle Age (36-59): 5911
#   Senior (60+): 2690

# %%
# Split data
train_df, val_df = train_test_split(
    df,
    test_size=0.2,
    stratify=df['class'],
    random_state=SEED
)

print(f"\nTraining samples: {len(train_df)}")
print(f"Validation samples: {len(val_df)}")
# Out:
# Training samples: 18966
# Validation samples: 4742

# %%
# ==================== DATA GENERATORS ====================
print("\n" + "=" * 60)
print("CREATING DATA GENERATORS")
print("=" * 60)

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=data_dir,
    x_col="filename",
    y_col="class",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=SEED
)

val_gen = val_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory=data_dir,
    x_col="filename",
    y_col="class",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

print("\nData generators created successfully!")
# Out:
# ============================================================
# CREATING DATA GENERATORS
# ============================================================
# Found 18966 validated image filenames belonging to 5 classes.
# Found 4742 validated image filenames belonging to 5 classes.
#
# Data generators created successfully!

# %%
# ==================== MODEL ARCHITECTURE ====================
print("\n" + "=" * 60)
print("BUILDING MODEL")
print("=" * 60)

model = Sequential([
    # Block 1
    Conv2D(64, (3, 3), activation='relu', padding='same',
           input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Block 2
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),

    # Block 3
    Conv2D(256, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(256, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(256, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.35),

    # Block 4
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.4),

    # Global pooling and dense layers
    GlobalAveragePooling2D(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),
    Dense(NUM_CLASSES, activation='softmax')
])
# Out:
# ============================================================
# BUILDING MODEL
# ============================================================
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 32, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 32, 32, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 32, 32, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 32, 32, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 16, 16, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 16, 16, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 16, 16, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,682,501 (21.68 MB)
#  Trainable params: 5,676,613 (21.65 MB)
#  Non-trainable params: 5,888 (23.00 KB)

# %%
# ==================== CALLBACKS ====================
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        'best_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

# %%
# ==================== TRAINING ====================
print("\n" + "=" * 60)
print("TRAINING MODEL")
print("=" * 60)

history = model.fit(
    train_gen,
    epochs=EPOCHS,
    validation_data=val_gen,
    callbacks=callbacks,
    verbose=1
)
# Out:
# ============================================================
# TRAINING MODEL
# ============================================================
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.3497 - loss: 1.8424
# Epoch 1: val_accuracy improved from -inf to 0.48629, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 191s 268ms/step - accuracy: 0.3497 - loss: 1.8420 - val_accuracy: 0.4863 - val_loss: 1.2759 - learning_rate: 0.0010
# Epoch 2/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.4501 - loss: 1.3583
# Epoch 2: val_accuracy improved from 0.48629 to 0.56284, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 133s 224ms/step - accuracy: 0.4501 - loss: 1.3582 - val_accuracy: 0.5628 - val_loss: 1.1153 - learning_rate: 0.0010
# Epoch 3/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.5628 - loss: 1.0982
# Epoch 3: val_accuracy did not improve from 0.56284
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - accuracy: 0.5629 - loss: 1.0982 - val_accuracy: 0.4612 - val_loss: 1.4164 - learning_rate: 0.0010
# Epoch 4/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.6055 - loss: 0.9854
# Epoch 4: val_accuracy did not improve from 0.56284
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - accuracy: 0.6055 - loss: 0.9854 - val_accuracy: 0.5418 - val_loss: 1.2184 - learning_rate: 0.0010
# Epoch 5/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.6297 - loss: 0.9135
# Epoch 5: val_accuracy did not improve from 0.56284
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 127s 215ms/step - accuracy: 0.6297 - loss: 0.9135 - val_accuracy: 0.5586 - val_loss: 1.0761 - learning_rate: 0.0010
# Epoch 6/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.6555 - loss: 0.8645
# Epoch 6: val_accuracy improved from 0.56284 to 0.58730, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 217ms/step - accuracy: 0.6555 - loss: 0.8645 - val_accuracy: 0.5873 - val_loss: 1.3363 - learning_rate: 0.0010
# Epoch 7/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6668 - loss: 0.8387
# Epoch 7: val_accuracy did not improve from 0.58730
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 218ms/step - accuracy: 0.6668 - loss: 0.8387 - val_accuracy: 0.5747 - val_loss: 1.1252 - learning_rate: 0.0010
# Epoch 8/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.6716 - loss: 0.8174
# Epoch 8: val_accuracy did not improve from 0.58730
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 141s 216ms/step - accuracy: 0.6716 - loss: 0.8174 - val_accuracy: 0.5557 - val_loss: 1.1823 - learning_rate: 0.0010
# Epoch 9/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.6871 - loss: 0.7829
# Epoch 9: val_accuracy improved from 0.58730 to 0.70076, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 217ms/step - accuracy: 0.6871 - loss: 0.7829 - val_accuracy: 0.7008 - val_loss: 0.7307 - learning_rate: 0.0010
# Epoch 10/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6903 - loss: 0.7621
# Epoch 10: val_accuracy improved from 0.70076 to 0.70793, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 218ms/step - accuracy: 0.6903 - loss: 0.7621 - val_accuracy: 0.7079 - val_loss: 0.7177 - learning_rate: 0.0010
# Epoch 11/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6983 - loss: 0.7466
# Epoch 11: val_accuracy did not improve from 0.70793
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 130s 219ms/step - accuracy: 0.6983 - loss: 0.7466 - val_accuracy: 0.6607 - val_loss: 0.7996 - learning_rate: 0.0010
# Epoch 12/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7041 - loss: 0.7438
# Epoch 12: val_accuracy did not improve from 0.70793
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 217ms/step - accuracy: 0.7041 - loss: 0.7438 - val_accuracy: 0.5529 - val_loss: 1.2048 - learning_rate: 0.0010
# Epoch 13/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7128 - loss: 0.7062
# Epoch 13: val_accuracy improved from 0.70793 to 0.71404, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 130s 219ms/step - accuracy: 0.7128 - loss: 0.7062 - val_accuracy: 0.7140 - val_loss: 0.6784 - learning_rate: 0.0010
# Epoch 14/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7144 - loss: 0.6941
# Epoch 14: val_accuracy improved from 0.71404 to 0.74757, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 130s 219ms/step - accuracy: 0.7144 - loss: 0.6941 - val_accuracy: 0.7476 - val_loss: 0.6264 - learning_rate: 0.0010
# Epoch 15/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7257 - loss: 0.6726
# Epoch 15: val_accuracy did not improve from 0.74757
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 130s 220ms/step - accuracy: 0.7257 - loss: 0.6726 - val_accuracy: 0.6432 - val_loss: 0.8942 - learning_rate: 0.0010
# Epoch 16/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7282 - loss: 0.6688
# Epoch 16: val_accuracy did not improve from 0.74757
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 218ms/step - accuracy: 0.7282 - loss: 0.6688 - val_accuracy: 0.7339 - val_loss: 0.6478 - learning_rate: 0.0010
# Epoch 17/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7298 - loss: 0.6660
# Epoch 17: val_accuracy did not improve from 0.74757
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 218ms/step - accuracy: 0.7298 - loss: 0.6660 - val_accuracy: 0.7147 - val_loss: 0.6759 - learning_rate: 0.0010
# Epoch 18/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7417 - loss: 0.6421
# Epoch 18: val_accuracy improved from 0.74757 to 0.75580, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 130s 220ms/step - accuracy: 0.7417 - loss: 0.6421 - val_accuracy: 0.7558 - val_loss: 0.5983 - learning_rate: 0.0010
# Epoch 19/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7426 - loss: 0.6301
# Epoch 19: val_accuracy did not improve from 0.75580
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 130s 219ms/step - accuracy: 0.7426 - loss: 0.6301 - val_accuracy: 0.7469 - val_loss: 0.5937 - learning_rate: 0.0010
# Epoch 20/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7432 - loss: 0.6325
# Epoch 20: val_accuracy did not improve from 0.75580
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 217ms/step - accuracy: 0.7432 - loss: 0.6325 - val_accuracy: 0.7516 - val_loss: 0.5837 - learning_rate: 0.0010
# Epoch 21/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7444 - loss: 0.6123
# Epoch 21: val_accuracy improved from 0.75580 to 0.76213, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 131s 220ms/step - accuracy: 0.7444 - loss: 0.6123 - val_accuracy: 0.7621 - val_loss: 0.5747 - learning_rate: 0.0010
# Epoch 22/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.7494 - loss: 0.5995
# Epoch 22: val_accuracy did not improve from 0.76213
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 131s 221ms/step - accuracy: 0.7494 - loss: 0.5995 - val_accuracy: 0.7560 - val_loss: 0.5934 - learning_rate: 0.0010
# Epoch 23/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7631 - loss: 0.5869
# Epoch 23: val_accuracy did not improve from 0.76213
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 130s 219ms/step - accuracy: 0.7631 - loss: 0.5870 - val_accuracy: 0.7328 - val_loss: 0.6796 - learning_rate: 0.0010
# Epoch 24/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7598 - loss: 0.5858
# Epoch 24: val_accuracy improved from 0.76213 to 0.76445, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 217ms/step - accuracy: 0.7598 - loss: 0.5858 - val_accuracy: 0.7644 - val_loss: 0.5912 - learning_rate: 0.0010
# Epoch 25/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7595 - loss: 0.5813
# Epoch 25: val_accuracy did not improve from 0.76445
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 217ms/step - accuracy: 0.7595 - loss: 0.5813 - val_accuracy: 0.7514 - val_loss: 0.6149 - learning_rate: 0.0010
# Epoch 26/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7626 - loss: 0.5781
# Epoch 26: val_accuracy improved from 0.76445 to 0.76740, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 217ms/step - accuracy: 0.7626 - loss: 0.5781 - val_accuracy: 0.7674 - val_loss: 0.5557 - learning_rate: 0.0010
# Epoch 27/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7661 - loss: 0.5670
# Epoch 27: val_accuracy improved from 0.76740 to 0.77710, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 218ms/step - accuracy: 0.7661 - loss: 0.5670 - val_accuracy: 0.7771 - val_loss: 0.5291 - learning_rate: 0.0010
# Epoch 28/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7709 - loss: 0.5572
# Epoch 28: val_accuracy did not improve from 0.77710
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 217ms/step - accuracy: 0.7709 - loss: 0.5573 - val_accuracy: 0.7088 - val_loss: 0.7347 - learning_rate: 0.0010
# Epoch 29/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7698 - loss: 0.5602
# Epoch 29: val_accuracy did not improve from 0.77710
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 127s 214ms/step - accuracy: 0.7698 - loss: 0.5602 - val_accuracy: 0.7752 - val_loss: 0.5365 - learning_rate: 0.0010
# Epoch 30/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7748 - loss: 0.5437
# Epoch 30: val_accuracy did not improve from 0.77710
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - accuracy: 0.7748 - loss: 0.5438 - val_accuracy: 0.7278 - val_loss: 0.6666 - learning_rate: 0.0010
# Epoch 31/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7763 - loss: 0.5452
# Epoch 31: val_accuracy did not improve from 0.77710
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 217ms/step - accuracy: 0.7763 - loss: 0.5452 - val_accuracy: 0.7695 - val_loss: 0.5798 - learning_rate: 0.0010
# Epoch 32/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7772 - loss: 0.5416
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 32: val_accuracy improved from 0.77710 to 0.78321, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 130s 219ms/step - accuracy: 0.7772 - loss: 0.5416 - val_accuracy: 0.7832 - val_loss: 0.5569 - learning_rate: 0.0010
# Epoch 33/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7863 - loss: 0.5141
# Epoch 33: val_accuracy did not improve from 0.78321
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - accuracy: 0.7863 - loss: 0.5141 - val_accuracy: 0.7815 - val_loss: 0.5196 - learning_rate: 5.0000e-04
# Epoch 34/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7940 - loss: 0.4977
# Epoch 34: val_accuracy improved from 0.78321 to 0.79355, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 218ms/step - accuracy: 0.7940 - loss: 0.4977 - val_accuracy: 0.7935 - val_loss: 0.5177 - learning_rate: 5.0000e-04
# Epoch 35/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8009 - loss: 0.4911
# Epoch 35: val_accuracy did not improve from 0.79355
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 218ms/step - accuracy: 0.8009 - loss: 0.4911 - val_accuracy: 0.7893 - val_loss: 0.5224 - learning_rate: 5.0000e-04
# Epoch 36/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.7992 - loss: 0.4884
# Epoch 36: val_accuracy did not improve from 0.79355
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - accuracy: 0.7992 - loss: 0.4884 - val_accuracy: 0.7876 - val_loss: 0.5195 - learning_rate: 5.0000e-04
# Epoch 37/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8148 - loss: 0.4657
# Epoch 37: val_accuracy did not improve from 0.79355
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 215ms/step - accuracy: 0.8148 - loss: 0.4657 - val_accuracy: 0.7819 - val_loss: 0.5300 - learning_rate: 5.0000e-04
# Epoch 38/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8075 - loss: 0.4708
# Epoch 38: val_accuracy did not improve from 0.79355
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 217ms/step - accuracy: 0.8075 - loss: 0.4708 - val_accuracy: 0.7838 - val_loss: 0.5252 - learning_rate: 5.0000e-04
# Epoch 39/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8039 - loss: 0.4757
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 39: val_accuracy did not improve from 0.79355
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - accuracy: 0.8039 - loss: 0.4757 - val_accuracy: 0.7794 - val_loss: 0.5306 - learning_rate: 5.0000e-04
# Epoch 40/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8188 - loss: 0.4506
# Epoch 40: val_accuracy did not improve from 0.79355
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - accuracy: 0.8188 - loss: 0.4506 - val_accuracy: 0.7889 - val_loss: 0.5134 - learning_rate: 2.5000e-04
# Epoch 41/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8161 - loss: 0.4497
# Epoch 41: val_accuracy did not improve from 0.79355
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - accuracy: 0.8161 - loss: 0.4497 - val_accuracy: 0.7805 - val_loss: 0.5380 - learning_rate: 2.5000e-04
# Epoch 42/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8151 - loss: 0.4469
# Epoch 42: val_accuracy did not improve from 0.79355
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 215ms/step - accuracy: 0.8151 - loss: 0.4469 - val_accuracy: 0.7885 - val_loss: 0.5241 - learning_rate: 2.5000e-04
# Epoch 43/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8211 - loss: 0.4345
# Epoch 43: val_accuracy did not improve from 0.79355
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - accuracy: 0.8211 - loss: 0.4345 - val_accuracy: 0.7860 - val_loss: 0.5127 - learning_rate: 2.5000e-04
# Epoch 44/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8231 - loss: 0.4246
# Epoch 44: val_accuracy did not improve from 0.79355
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - accuracy: 0.8231 - loss: 0.4246 - val_accuracy: 0.7826 - val_loss: 0.5285 - learning_rate: 2.5000e-04
# Epoch 45/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8296 - loss: 0.4227
# Epoch 45: val_accuracy did not improve from 0.79355
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 129s 217ms/step - accuracy: 0.8296 - loss: 0.4227 - val_accuracy: 0.7893 - val_loss: 0.5152 - learning_rate: 2.5000e-04
# Epoch 46/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8251 - loss: 0.4304
# Epoch 46: val_accuracy did not improve from 0.79355
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - accuracy: 0.8251 - loss: 0.4304 - val_accuracy: 0.7900 - val_loss: 0.5183 - learning_rate: 2.5000e-04
# Epoch 47/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8332 - loss: 0.4096
# Epoch 47: val_accuracy did not improve from 0.79355
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - accuracy: 0.8332 - loss: 0.4096 - val_accuracy: 0.7904 - val_loss: 0.5259 - learning_rate: 2.5000e-04
# Epoch 48/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8374 - loss: 0.4067
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 48: val_accuracy improved from 0.79355 to 0.79566, saving model to best_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 128s 216ms/step - accuracy: 0.8374 - loss: 0.4067 - val_accuracy: 0.7957 - val_loss: 0.5215 - learning_rate: 2.5000e-04
# Epoch 49/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8379 - loss: 0.3995
# Epoch 49: val_accuracy did not improve from 0.79566
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 130s 219ms/step - accuracy: 0.8379 - loss: 0.3995 - val_accuracy: 0.7933 - val_loss: 0.5178 - learning_rate: 1.2500e-04
# Epoch 50/50
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8352 - loss: 0.3966
# Epoch 50: val_accuracy did not improve from 0.79566
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 130s 219ms/step - accuracy: 0.8352 - loss: 0.3966 - val_accuracy: 0.7916 - val_loss: 0.5155 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 43.

# %%
# ==================== TRAINING VISUALIZATION ====================
print("\n" + "=" * 60)
print("TRAINING RESULTS")
print("=" * 60)

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation', linewidth=2)
plt.title('Model Accuracy', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation', linewidth=2)
plt.title('Model Loss', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ============================================================
# TRAINING RESULTS
# ============================================================

# %%
# ==================== EVALUATION ====================
print("\n" + "=" * 60)
print("MODEL EVALUATION")
print("=" * 60)

val_loss, val_acc = model.evaluate(val_gen, verbose=0)
print(f"\nValidation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_acc*100:.2f}%")
# Out:
# ============================================================
# MODEL EVALUATION
# ============================================================
#
# Validation Loss: 0.5127
# Validation Accuracy: 78.60%

# %%
# Get predictions
val_gen.reset()
predictions = model.predict(val_gen, verbose=0)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = val_gen.classes

# %%
# Classification report
print("\n" + "=" * 60)
print("CLASSIFICATION REPORT")
print("=" * 60)
print(classification_report(true_classes, predicted_classes,
                          target_names=age_group_labels, digits=3))
# Out:
# ============================================================
# CLASSIFICATION REPORT
# ============================================================
#                     precision    recall  f1-score   support
#
#       Child (0-10)      0.907     0.910     0.909       644
#   Teenager (11-17)      0.528     0.468     0.496       203
#      Adult (18-35)      0.821     0.893     0.856      2175
# Middle Age (36-59)      0.689     0.602     0.642      1182
#       Senior (60+)      0.756     0.730     0.743       538
#
#           accuracy                          0.786      4742
#          macro avg      0.740     0.721     0.729      4742
#       weighted avg      0.780     0.786     0.781      4742

# %%
# Get predictions - Make sure this runs BEFORE the per-class accuracy section
val_gen.reset()
predictions = model.predict(val_gen, verbose=0)
predicted_classes = np.argmax(predictions, axis=1)

# Get true labels - THIS IS THE KEY FIX
true_classes = np.array(val_gen.classes)  # Convert to NumPy array

# Per-class accuracy
print("\n" + "=" * 60)
print("PER-CLASS ACCURACY")
print("=" * 60)
for i in range(NUM_CLASSES):
    mask = true_classes == i
    if mask.sum() > 0:
        correct = (predicted_classes[mask] == true_classes[mask]).sum()
        total = mask.sum()
        accuracy = correct / total
        print(f"{age_group_labels[i]:20s}: {accuracy:.3f} ({accuracy*100:5.1f}%) - {correct:4d}/{total:4d} correct")
# Out:
# ============================================================
# PER-CLASS ACCURACY
# ============================================================
# Child (0-10)        : 0.910 ( 91.0%) -  586/ 644 correct
# Teenager (11-17)    : 0.468 ( 46.8%) -   95/ 203 correct
# Adult (18-35)       : 0.893 ( 89.3%) - 1942/2175 correct
# Middle Age (36-59)  : 0.602 ( 60.2%) -  711/1182 correct
# Senior (60+)        : 0.730 ( 73.0%) -  393/ 538 correct

# %%
# Confusion Matrix
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=age_group_labels,
            yticklabels=age_group_labels,
            cbar_kws={'label': 'Count'})
plt.title('Confusion Matrix', fontsize=14, fontweight='bold')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# ==================== SAMPLE PREDICTIONS ====================
print("\n" + "=" * 60)
print("VISUALIZING SAMPLE PREDICTIONS")
print("=" * 60)

val_gen.reset()
x_batch, y_batch = next(val_gen)
predictions_batch = model.predict(x_batch, verbose=0)

plt.figure(figsize=(16, 12))
for i in range(min(16, len(x_batch))):
    plt.subplot(4, 4, i+1)
    plt.imshow(x_batch[i])

    true_idx = np.argmax(y_batch[i])
    pred_idx = np.argmax(predictions_batch[i])
    confidence = predictions_batch[i][pred_idx] * 100

    color = 'green' if true_idx == pred_idx else 'red'

    plt.title(f'True: {age_group_labels[true_idx]}\n'
             f'Pred: {age_group_labels[pred_idx]}\n'
             f'Conf: {confidence:.1f}%',
             color=color, fontsize=9)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ============================================================
# VISUALIZING SAMPLE PREDICTIONS
# ============================================================

# %%
# ==================== SAVE MODEL ====================
model.save("age_classification_final.keras")
print("\n" + "=" * 60)
print("MODEL SAVED: age_classification_final.keras")
print("=" * 60)
# Out:
# ============================================================
# MODEL SAVED: age_classification_final.keras
# ============================================================

# %%
# ==================== PREDICTION FUNCTION ====================
def predict_age_from_image(image_path):
    """
    Predict age group for a single image

    Args:
        image_path: Path to the image file

    Returns:
        predicted_class: Index of predicted class
        confidence: Confidence percentage
    """
    from tensorflow.keras.preprocessing import image

    img = image.load_img(image_path, target_size=(IMG_SIZE, IMG_SIZE))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0

    prediction = model.predict(img_array, verbose=0)
    predicted_class = np.argmax(prediction)
    confidence = prediction[0][predicted_class] * 100

    print(f"\nPrediction for: {image_path}")
    print(f"Age Group: {age_group_labels[predicted_class]}")
    print(f"Confidence: {confidence:.2f}%")
    print("\nAll probabilities:")
    for i, prob in enumerate(prediction[0]):
        print(f"  {age_group_labels[i]:20s}: {prob*100:5.2f}%")

    return predicted_class, confidence

print("\n" + "=" * 60)
print("PROJECT COMPLETE!")
print("=" * 60)
print("\nTo predict on a new image, use:")
print(predict_age_from_image('/content/sample.jpg'))
# Out:
# ============================================================
# PROJECT COMPLETE!
# ============================================================
#
# To predict on a new image, use:
#
# Prediction for: /content/sample.jpg
# Age Group: Adult (18-35)
# Confidence: 89.84%
#
# All probabilities:
#   Child (0-10)        :  0.03%
#   Teenager (11-17)    :  6.90%
#   Adult (18-35)       : 89.84%
#   Middle Age (36-59)  :  2.04%
#   Senior (60+)        :  1.19%
# (np.int64(2), np.float32(89.841965))
